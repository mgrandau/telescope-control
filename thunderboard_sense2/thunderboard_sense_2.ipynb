# %%
import serial
import datetime
import time
import numpy as np
import matplotlib.pyplot as plt
import appnope
import glob 
import pandas as pd
import platform
import sys
import argparse

from pprint import pprint

os_platform = platform.system()

import serial.tools.list_ports
ports = list(serial.tools.list_ports.comports())

pid = '1366'
hid = '1015'

for p in ports:
	#print('Serial port found:')
	#print(p[1])
	#print('Port pid and hid')
	#print(p.hwid)
	hwid_save = p.hwid
	if pid and hid in p.hwid:
		print('Found the Thunderboard device to open with PID = {} and HID = {}!'.format(pid, hid))
try:
	# ser_addr = [x for x in ports if x[1]=='J-Link OB'][0][0]
	ser_addr = [x for x in ports if pid and hid in x.hwid][0][0]
except IndexError:
	print('No serial address found.\n Is the thunderboard connected using USB?') 
	if os_platform in ['Darwin', 'Linux']:
		print('Check for /dev/tty.usbmodem by $ ls /dev/tty.*')	
	elif os_platform in ['Windows']:
		print('Check for COM in Device Manager')
	sys.exit(1) 	

# fix sensor keys to match the strings from the Thunderboard
sensor_keys = ['TVOC', 'Pressure', 'SoundLevel', 'Amb light', 
				'eCO2', 'HALL: Mag', 'Temp', 'Humidity', 'UV Index']

def TimestampMillisec64():
	return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000) 

# serial parameters and serial opening
baudrate = 115200

ser = serial.Serial(ser_addr, baudrate = baudrate, timeout = 2)
ser.is_open
time.sleep(0.15)
# Out:
# Found the Thunderboard device to open with PID = 1366 and HID = 1015!

# %%
results = {}
for k in sensor_keys:
	results[k] = {}
	results[k]['value'] = np.array([])
	results[k]['time'] = np.array([])
	results[k]['units'] = np.array([])

# flush serial buffer
ser.read(ser.in_waiting)
t_junk = ser.readline()

t_start = TimestampMillisec64()
elapsed_time = (TimestampMillisec64() - t_start)/1000

while(elapsed_time < float(10)):
	t = str(ser.readline())
	print(t)  # add this
	
	# Remove for iOS 
#		if len(t) == 3:
#			print('Serial read timeout. \n Is the bluetooth app connected AND diplaying Environmental data?')
#			# close serial port
#			ser.close()
#			sys.exit(2)		
	

# close serial port
ser.close()	
pprint(ports)
# Out:
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b'[I] AIO out: 0=0\r\n'
# b'[I] AIO out: 1=0\r\n'
# b'[I] Connection opened\r\n'
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b'[I] IMU enable\r\n'
# b'[I] IMU: ORI : 0898,2977,1706\r\n'
# b'[I] IMU: ACC : -462,-1090,-510\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0875,3529,1507\r\n'
# b'[I] IMU: ACC : 0857,0072,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0756,3865,1501\r\n'
# b'[I] IMU: ACC : 0857,0065,0495\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0626,4076,1492\r\n'
# b'[I] IMU: ACC : 0875,0057,0499\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0523,4276,1499\r\n'
# b'[I] IMU: ACC : 0864,0066,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0424,4442,1494\r\n'
# b'[I] IMU: ACC : 0859,0058,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0323,4585,1477\r\n'
# b'[I] IMU: ACC : 0857,0059,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0249,4716,1478\r\n'
# b'[I] IMU: ACC : 0862,0051,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0165,4841,1454\r\n'
# b'[I] IMU: ACC : 0864,0060,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0093,4957,1433\r\n'
# b'[I] IMU: ACC : 0859,0060,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : 0005,5048,1390\r\n'
# b'[I] IMU: ACC : 0858,0061,0483\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -075,5134,1341\r\n'
# b'[I] IMU: ACC : 0863,0062,0486\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -115,5216,1351\r\n'
# b'[I] IMU: ACC : 0851,0059,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -167,5263,1318\r\n'
# b'[I] IMU: ACC : 0850,0066,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -237,5326,1266\r\n'
# b'[I] IMU: ACC : 0875,0062,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -306,5398,1216\r\n'
# b'[I] IMU: ACC : 0869,0058,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -367,5465,1170\r\n'
# b'[I] IMU: ACC : 0860,0063,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -409,5507,1127\r\n'
# b'[I] IMU: ACC : 0862,0070,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -462,5542,1084\r\n'
# b'[I] IMU: ACC : 0854,0063,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -472,5571,1067\r\n'
# b'[I] IMU: ACC : 0855,0060,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -490,5603,1037\r\n'
# b'[I] IMU: ACC : 0857,0070,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -517,5627,1008\r\n'
# b'[I] IMU: ACC : 0860,0064,0507\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -561,5667,0953\r\n'
# b'[I] IMU: ACC : 0859,0062,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -587,5690,0907\r\n'
# b'[I] IMU: ACC : 0846,0061,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -618,5699,0852\r\n'
# b'[I] IMU: ACC : 0853,0069,0487\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -637,5709,0817\r\n'
# b'[I] IMU: ACC : 0858,0057,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -657,5728,0771\r\n'
# b'[I] IMU: ACC : 0860,0059,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -685,5742,0710\r\n'
# b'[I] IMU: ACC : 0858,0073,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -692,5757,0678\r\n'
# b'[I] IMU: ACC : 0865,0062,0477\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -698,5774,0637\r\n'
# b'[I] IMU: ACC : 0859,0062,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -731,5786,0578\r\n'
# b'[I] IMU: ACC : 0861,0056,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -734,5784,0539\r\n'
# b'[I] IMU: ACC : 0858,0061,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -747,5797,0479\r\n'
# b'[I] IMU: ACC : 0859,0070,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -771,5806,0421\r\n'
# b'[I] IMU: ACC : 0865,0060,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -768,5819,0388\r\n'
# b'[I] IMU: ACC : 0863,0062,0484\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -759,5831,0366\r\n'
# b'[I] IMU: ACC : 0862,0074,0487\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -775,5842,0331\r\n'
# b'[I] IMU: ACC : 0861,0065,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -767,5849,0301\r\n'
# b'[I] IMU: ACC : 0861,0062,0498\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -783,5852,0250\r\n'
# b'[I] IMU: ACC : 0856,0054,0482\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -757,5858,0240\r\n'
# b'[I] IMU: ACC : 0859,0067,0500\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -767,5859,0190\r\n'
# b'[I] IMU: ACC : 0859,0050,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -766,5858,0144\r\n'
# b'[I] IMU: ACC : 0863,0073,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -769,5873,0103\r\n'
# b'[I] IMU: ACC : 0851,0063,0482\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -765,5862,0060\r\n'
# b'[I] IMU: ACC : 0859,0070,0505\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -778,5865,0008\r\n'
# b'[I] IMU: ACC : 0866,0061,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -795,5878,-049\r\n'
# b'[I] IMU: ACC : 0851,0052,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -793,5871,-087\r\n'
# b'[I] IMU: ACC : 0852,0069,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -796,5865,-131\r\n'
# b'[I] IMU: ACC : 0866,0059,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -778,5879,-154\r\n'
# b'[I] IMU: ACC : 0859,0060,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -771,5885,-187\r\n'
# b'[I] IMU: ACC : 0860,0061,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -762,5885,-222\r\n'
# b'[I] IMU: ACC : 0865,0065,0484\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -786,5885,-287\r\n'
# b'[I] IMU: ACC : 0855,0052,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -788,5876,-327\r\n'
# b'[I] IMU: ACC : 0861,0061,0486\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -790,5871,-371\r\n'
# b'[I] IMU: ACC : 0856,0059,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -773,5868,-396\r\n'
# b'[I] IMU: ACC : 0849,0061,0500\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -773,5853,-431\r\n'
# b'[I] IMU: ACC : 0864,0056,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -769,5857,-473\r\n'
# b'[I] IMU: ACC : 0861,0067,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -778,5860,-511\r\n'
# b'[I] IMU: ACC : 0855,0067,0479\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -767,5855,-541\r\n'
# b'[I] IMU: ACC : 0857,0064,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -760,5849,-583\r\n'
# b'[I] IMU: ACC : 0868,0058,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -750,5866,-610\r\n'
# b'[I] IMU: ACC : 0858,0071,0478\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -750,5860,-653\r\n'
# b'[I] IMU: ACC : 0864,0063,0484\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -733,5870,-665\r\n'
# b'[I] IMU: ACC : 0846,0054,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -728,5865,-691\r\n'
# b'[I] IMU: ACC : 0866,0061,0499\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -733,5869,-740\r\n'
# b'[I] IMU: ACC : 0862,0058,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -721,5886,-763\r\n'
# b'[I] IMU: ACC : 0869,0065,0498\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -741,5898,-812\r\n'
# b'[I] IMU: ACC : 0867,0065,0479\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -747,5898,-841\r\n'
# b'[I] IMU: ACC : 0875,0063,0498\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -751,5913,-879\r\n'
# b'[I] IMU: ACC : 0850,0060,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -736,5907,-905\r\n'
# b'[I] IMU: ACC : 0867,0061,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -733,5909,-932\r\n'
# b'[I] IMU: ACC : 0866,0060,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -751,5911,-994\r\n'
# b'[I] IMU: ACC : 0863,0063,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -730,5910,-1010\r\n'
# b'[I] IMU: ACC : 0861,0061,0484\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -713,5917,-1028\r\n'
# b'[I] IMU: ACC : 0846,0062,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -713,5901,-1059\r\n'
# b'[I] IMU: ACC : 0858,0058,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -704,5898,-1086\r\n'
# b'[I] IMU: ACC : 0853,0052,0484\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -705,5885,-1125\r\n'
# b'[I] IMU: ACC : 0854,0050,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -698,5872,-1157\r\n'
# b'[I] IMU: ACC : 0850,0054,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -680,5864,-1173\r\n'
# b'[I] IMU: ACC : 0858,0066,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -692,5856,-1214\r\n'
# b'[I] IMU: ACC : 0870,0062,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -706,5869,-1250\r\n'
# b'[I] IMU: ACC : 0870,0057,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -736,5882,-1317\r\n'
# b'[I] IMU: ACC : 0864,0063,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -735,5884,-1356\r\n'
# b'[I] IMU: ACC : 0863,0061,0483\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -741,5886,-1402\r\n'
# b'[I] IMU: ACC : 0855,0060,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -743,5875,-1439\r\n'
# b'[I] IMU: ACC : 0854,0065,0500\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -741,5869,-1467\r\n'
# b'[I] IMU: ACC : 0869,0060,0499\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -764,5875,-1522\r\n'
# b'[I] IMU: ACC : 0858,0054,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -754,5870,-1547\r\n'
# b'[I] IMU: ACC : 0851,0074,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -771,5855,-1597\r\n'
# b'[I] IMU: ACC : 0861,0058,0486\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -758,5871,-1628\r\n'
# b'[I] IMU: ACC : 0854,0056,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -770,5868,-1686\r\n'
# b'[I] IMU: ACC : 0859,0072,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -749,5869,-1695\r\n'
# b'[I] IMU: ACC : 0860,0062,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -758,5877,-1735\r\n'
# b'[I] IMU: ACC : 0861,0068,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -766,5888,-1777\r\n'
# b'[I] IMU: ACC : 0851,0064,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -745,5875,-1799\r\n'
# b'[I] IMU: ACC : 0850,0065,0479\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -732,5859,-1823\r\n'
# b'[I] IMU: ACC : 0854,0060,0500\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -746,5854,-1870\r\n'
# b'[I] IMU: ACC : 0872,0071,0483\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -751,5870,-1907\r\n'
# b'[I] IMU: ACC : 0867,0059,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -733,5884,-1935\r\n'
# b'[I] IMU: ACC : 0862,0066,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -752,5887,-1989\r\n'
# b'[I] IMU: ACC : 0861,0063,0503\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -754,5889,-2032\r\n'
# b'[I] IMU: ACC : 0857,0059,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -715,5883,-2022\r\n'
# b'[I] IMU: ACC : 0854,0053,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -704,5877,-2038\r\n'
# b'[I] IMU: ACC : 0862,0071,0502\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -712,5881,-2078\r\n'
# b'[I] IMU: ACC : 0861,0053,0495\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -697,5881,-2091\r\n'
# b'[I] IMU: ACC : 0851,0062,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -711,5869,-2138\r\n'
# b'[I] IMU: ACC : 0863,0067,0482\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -729,5874,-2185\r\n'
# b'[I] IMU: ACC : 0872,0061,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -743,5902,-2233\r\n'
# b'[I] IMU: ACC : 0872,0068,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -744,5911,-2275\r\n'
# b'[I] IMU: ACC : 0853,0059,0500\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -729,5895,-2298\r\n'
# b'[I] IMU: ACC : 0867,0060,0501\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -740,5911,-2347\r\n'
# b'[I] IMU: ACC : 0866,0061,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -736,5925,-2371\r\n'
# b'[I] IMU: ACC : 0863,0056,0500\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -748,5921,-2415\r\n'
# b'[I] IMU: ACC : 0856,0057,0498\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -750,5911,-2462\r\n'
# b'[I] IMU: ACC : 0856,0052,0486\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -748,5903,-2496\r\n'
# b'[I] IMU: ACC : 0860,0064,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -759,5896,-2539\r\n'
# b'[I] IMU: ACC : 0858,0067,0481\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -776,5889,-2598\r\n'
# b'[I] IMU: ACC : 0863,0061,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -770,5892,-2625\r\n'
# b'[I] IMU: ACC : 0862,0062,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -769,5899,-2662\r\n'
# b'[I] IMU: ACC : 0855,0062,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -793,5887,-2720\r\n'
# b'[I] IMU: ACC : 0860,0066,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -779,5885,-2752\r\n'
# b'[I] IMU: ACC : 0867,0057,0484\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -757,5893,-2780\r\n'
# b'[I] IMU: ACC : 0859,0063,0478\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -744,5896,-2797\r\n'
# b'[I] IMU: ACC : 0864,0064,0480\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -769,5904,-2846\r\n'
# b'[I] IMU: ACC : 0857,0052,0498\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -744,5900,-2860\r\n'
# b'[I] IMU: ACC : 0852,0058,0484\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -740,5881,-2892\r\n'
# b'[I] IMU: ACC : 0854,0055,0478\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -750,5868,-2938\r\n'
# b'[I] IMU: ACC : 0849,0054,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -735,5848,-2961\r\n'
# b'[I] IMU: ACC : 0855,0052,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -723,5854,-2982\r\n'
# b'[I] IMU: ACC : 0865,0065,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -730,5854,-3020\r\n'
# b'[I] IMU: ACC : 0872,0066,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -725,5874,-3051\r\n'
# b'[I] IMU: ACC : 0857,0053,0496\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -719,5873,-3088\r\n'
# b'[I] IMU: ACC : 0862,0062,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -739,5883,-3142\r\n'
# b'[I] IMU: ACC : 0875,0058,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -740,5900,-3184\r\n'
# b'[I] IMU: ACC : 0873,0062,0483\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -742,5912,-3223\r\n'
# b'[I] IMU: ACC : 0866,0069,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -748,5910,-3260\r\n'
# b'[I] IMU: ACC : 0863,0053,0491\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -762,5910,-3311\r\n'
# b'[I] IMU: ACC : 0870,0055,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -758,5924,-3348\r\n'
# b'[I] IMU: ACC : 0854,0060,0496\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -756,5910,-3384\r\n'
# b'[I] IMU: ACC : 0855,0063,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -745,5901,-3412\r\n'
# b'[I] IMU: ACC : 0864,0068,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -746,5911,-3443\r\n'
# b'[I] IMU: ACC : 0867,0056,0487\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -728,5933,-3466\r\n'
# b'[I] IMU: ACC : 0866,0056,0495\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -711,5932,-3501\r\n'
# b'[I] IMU: ACC : 0856,0041,0482\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -697,5915,-3540\r\n'
# b'[I] IMU: ACC : 0858,0046,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -679,5917,-3565\r\n'
# b'[I] IMU: ACC : 0861,0051,0485\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -687,5914,-3602\r\n'
# b'[I] IMU: ACC : 0860,0061,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -679,5912,-3617\r\n'
# b'[I] IMU: ACC : 0857,0057,0480\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -680,5904,-3653\r\n'
# b'[I] IMU: ACC : 0854,0059,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -689,5899,-3691\r\n'
# b'[I] IMU: ACC : 0864,0058,0492\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -698,5893,-3725\r\n'
# b'[I] IMU: ACC : 0865,0070,0494\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -706,5906,-3752\r\n'
# b'[I] IMU: ACC : 0859,0063,0495\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -686,5909,-3768\r\n'
# b'[I] IMU: ACC : 0854,0050,0489\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -691,5900,-3804\r\n'
# b'[I] IMU: ACC : 0857,0064,0504\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -685,5893,-3830\r\n'
# b'[I] IMU: ACC : 0862,0065,0488\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -704,5888,-3869\r\n'
# b'[I] IMU: ACC : 0859,0068,0496\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -711,5890,-3906\r\n'
# b'[I] IMU: ACC : 0857,0065,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -678,5890,-3901\r\n'
# b'[I] IMU: ACC : 0863,0054,0499\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -692,5906,-3951\r\n'
# b'[I] IMU: ACC : 0856,0061,0479\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -713,5902,-4005\r\n'
# b'[I] IMU: ACC : 0870,0066,0490\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -724,5911,-4033\r\n'
# b'[I] IMU: ACC : 0864,0071,0482\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -729,5913,-4070\r\n'
# b'[I] IMU: ACC : 0868,0053,0498\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -739,5916,-4108\r\n'
# b'[I] IMU: ACC : 0867,0068,0481\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -764,5920,-4157\r\n'
# b'[I] IMU: ACC : 0870,0062,0495\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -769,5920,-4194\r\n'
# b'[I] IMU: ACC : 0855,0060,0499\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -750,5920,-4215\r\n'
# b'[I] IMU: ACC : 0845,0062,0486\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -767,5904,-4268\r\n'
# b'[I] IMU: ACC : 0861,0062,0493\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -765,5912,-4302\r\n'
# b'[I] IMU: ACC : 0863,0066,0496\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] IMU: ORI : -753,5918,-4322\r\n'
# b'[I] IMU: ACC : 0855,0058,0497\r\n'
# b'[E] [E: 0x0002] Failed to send characteristic notification\n'
# b'[I] AIO out: 0=0\r\n'
# b'[I] AIO out: 1=0\r\n'
# b'[I] IMU disable\r\n'
# b'[I] Connection closed\r\n'
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-2-640608cdae45> in <module>
#      14
#      15 while(elapsed_time < float(10)):
# ---> 16         t = str(ser.readline())
#      17         print(t)  # add this
#      18
#
# ~/.local/lib/python3.8/site-packages/serial/serialposix.py in read(self, size)
#     593                     # behavior that they are always ready to read immediately
#     594                     # but reading returns nothing.
# --> 595                     raise SerialException(
#     596                         'device reports readiness to read but returned no data '
#     597                         '(device disconnected or multiple access on port?)')
#
# SerialException: device reports readiness to read but returned no data (device disconnected or multiple access on port?)

# %%
	now = datetime.datetime.now() # current date and time for saving files 
	date_time = now.strftime("%Y_%m_%d_%H_%M_%S")

	os_platform = platform.system()
	appnope.nope()
	plt.style.use('ggplot')

	# temporary sensor keys for input arguments (no spaces)
	sensor_keys = ['TVOC', 'Pressure', 'SoundLevel', 'AmbLight', 
			  	  'eCO2', 'HALL', 'Temp', 'Humidity', 'UVIndex']
	sensor_list = ', '.join(sensor_keys)

	parser = argparse.ArgumentParser()
	parser.add_argument("--time", 
						help="The time for data collection in seconds", 
						default = 10)
	parser.add_argument("--sensor", 
						help="The name of the sensor to plot and display (can be all)\nOptions are: {}".format(sensor_list), 
						default = 'Humidity')
	args = parser.parse_args()
	run_time = float(args.time) # seconds [TODO: input]
	sensor_to_display = str(args.sensor) # 'Humidity' # [TODO: input]

	if sensor_to_display == 'AmbLight':
		sensor_to_display = 'Amb light'
	if sensor_to_display == 'HALL':
		sensor_to_display = 'HALL: Mag'
	if sensor_to_display == 'UVIndex':
		sensor_to_display = 'UV Index'

	# fix sensor keys to match the strings from the Thunderboard
	sensor_keys = ['TVOC', 'Pressure', 'SoundLevel', 'Amb light', 
			  	  'eCO2', 'HALL: Mag', 'Temp', 'Humidity', 'UV Index']

	def TimestampMillisec64():
	    return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000) 

	# serial parameters and serial opening
	baudrate = 115200

	import serial.tools.list_ports
	ports = list(serial.tools.list_ports.comports())
	
	pid = '1366'
	hid = '1015'

	for p in ports:
		#print('Serial port found:')
		#print(p[1])
		#print('Port pid and hid')
		#print(p.hwid)
		hwid_save = p.hwid
		if pid and hid in p.hwid:
			print('Found the Thunderboard device to open with PID = {} and HID = {}!'.format(pid, hid))
	try:
		# ser_addr = [x for x in ports if x[1]=='J-Link OB'][0][0]
		ser_addr = [x for x in ports if pid and hid in x.hwid][0][0]
	except IndexError:
		print('No serial address found.\n Is the thunderboard connected using USB?') 
		if os_platform in ['Darwin', 'Linux']:
			print('Check for /dev/tty.usbmodem by $ ls /dev/tty.*')	
		elif os_platform in ['Windows']:
			print('Check for COM in Device Manager')
		sys.exit(1) 	

	'''
	if os_platform == 'Darwin':  # MAC 
		print("Found these devices: " + glob.glob("/dev/tty.usbmodem*")[0])
		ser_addr = glob.glob("/dev/tty.usbmodem*")[0]
	elif os_platform == 'Windows':
		print("Found these devices: " + glob.glob("/dev/tty.usbmodem*")[0])
		ser_addr = glob.glob("/dev/tty.usbmodem*")[0]
	elif os_platform == 'Linux':
		print("Found these devices: " + glob.glob("/dev/tty.usbmodem*")[0])
		ser_addr = glob.glob("/dev/tty.usbmodem*")[0]
	'''

	ser = serial.Serial(ser_addr, baudrate = baudrate, timeout = 2)
	ser.is_open
	time.sleep(0.15)

	results = {}
	for k in sensor_keys:
		results[k] = {}
		results[k]['value'] = np.array([])
		results[k]['time'] = np.array([])
		results[k]['units'] = np.array([])

	# flush serial buffer
	ser.read(ser.in_waiting)
	t_junk = ser.readline()

	t_start = TimestampMillisec64()
	elapsed_time = (TimestampMillisec64() - t_start)/1000

	while(elapsed_time < run_time):
		t = str(ser.readline())
		print(t)  # add this
		
		# Remove for iOS 
#		if len(t) == 3:
#			print('Serial read timeout. \n Is the bluetooth app connected AND diplaying Environmental data?')
#			# close serial port
#			ser.close()
#			sys.exit(2)		
		
		elapsed_time = (TimestampMillisec64() - t_start) / 1000

		for k in sensor_keys:
			if k in t:
				if k == 'UV Index':
					results[k]['value'] = np.append(results[k]['value'], 
													float(t.split('=')[1].split(' ')[1].replace("\\r\\n'",'')))
					results[k]['units'] = np.append(results[k]['units'], 'index')
				else:
					results[k]['value'] = np.append(results[k]['value'], 
													float(t.split('=')[1].split(' ')[1]))
					# fix units for TVOC and eCO2
					if k == 'eCO2':
						results[k]['units'] = np.append(results[k]['units'], 'ppm')
					elif k == 'TVOC':
						results[k]['units'] = np.append(results[k]['units'], 'ppb')
					else:
						results[k]['units'] = np.append(results[k]['units'], 
													t.split('=')[1].split(' ')[2].replace("\\r\\n'",''))

				results[k]['time'] = np.append(results[k]['time'], elapsed_time)
				if ((k == sensor_to_display) or (sensor_to_display == 'all')):
					print('At {:2.2f} [s] Measured {} sensor: {:4.2f} {}'.format(elapsed_time, 
						k, results[k]['value'][-1], results[k]['units'][-1]))

	# close serial port
	ser.close()

	# plot and save data
	if sensor_to_display == 'all':
		fig, axs = plt.subplots(3,3, figsize = (10, 10))
		sensors_to_plot = sensor_keys
		for idx,k in enumerate(sensors_to_plot):
			axs[int(idx/3)][idx % 3].plot(results[k]['time'], 
					results[k]['value'], marker='x', label = k)
			axs[int(idx/3)][idx % 3].legend() 
			axs[int(idx/3)][idx % 3].set_ylabel(results[k]['units'][-1])
			axs[int(idx/3)][idx % 3].set_xlabel('Time [s]')

	else:
		sensors_to_plot = [sensor_to_display]
		fig, axs = plt.subplots(figsize = (10, 10))
		for idx,k in enumerate(sensors_to_plot):
			axs.plot(results[k]['time'], 
						results[k]['value'], marker='x', label = k)
			axs.set_ylabel(results[k]['units'][-1])
		axs.set_xlabel('Time [s]')
		axs.legend() 


	fig.tight_layout()
	fig.savefig('measured_{}_{}.png'.format(sensor_to_display, date_time))
	# blocking show
	plt.ioff()
	plt.show()
				
	# https://stackoverflow.com/questions/13575090/construct-pandas-dataframe-from-items-in-nested-dictionary
	# save dictionary to CSV file by first converting to a pandas dataframe
	df = pd.DataFrame.from_dict({i + '_' + j: results[i][j] 
	                           for i in results.keys() 
	                           for j in results[i].keys()},
	                       orient='index')
	df = df.transpose()
	df.to_csv('data_{}.csv'.format(date_time), index=False)
# Out:
#   File "/tmp/ipykernel_219029/2588557622.py", line 1
#     import thunderboard-reader
#                        ^
# SyntaxError: invalid syntax
