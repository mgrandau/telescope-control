# %%
import serial
import datetime
import time
import numpy as np
import matplotlib.pyplot as plt
import appnope
import glob 
import pandas as pd
import platform
import sys
import argparse

from pprint import pprint

os_platform = platform.system()

import serial.tools.list_ports
ports = list(serial.tools.list_ports.comports())

pid = '1366'
hid = '1015'

for p in ports:
	#print('Serial port found:')
	#print(p[1])
	#print('Port pid and hid')
	#print(p.hwid)
	hwid_save = p.hwid
	if pid and hid in p.hwid:
		print('Found the Thunderboard device to open with PID = {} and HID = {}!'.format(pid, hid))
try:
	# ser_addr = [x for x in ports if x[1]=='J-Link OB'][0][0]
	ser_addr = [x for x in ports if pid and hid in x.hwid][0][0]
except IndexError:
	print('No serial address found.\n Is the thunderboard connected using USB?') 
	if os_platform in ['Darwin', 'Linux']:
		print('Check for /dev/tty.usbmodem by $ ls /dev/tty.*')	
	elif os_platform in ['Windows']:
		print('Check for COM in Device Manager')
	sys.exit(1) 	

# fix sensor keys to match the strings from the Thunderboard
sensor_keys = ['TVOC', 'Pressure', 'SoundLevel', 'Amb light', 
				'eCO2', 'HALL: Mag', 'Temp', 'Humidity', 'UV Index']

def TimestampMillisec64():
	return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000) 

# serial parameters and serial opening
baudrate = 115200

ser = serial.Serial(ser_addr, baudrate = baudrate, timeout = 2)
ser.is_open
time.sleep(0.15)

results = {}
for k in sensor_keys:
	results[k] = {}
	results[k]['value'] = np.array([])
	results[k]['time'] = np.array([])
	results[k]['units'] = np.array([])

# flush serial buffer
ser.read(ser.in_waiting)
t_junk = ser.readline()

t_start = TimestampMillisec64()
elapsed_time = (TimestampMillisec64() - t_start)/1000

while(elapsed_time < float(10)):
	t = str(ser.readline())
	print(t)  # add this
	
	# Remove for iOS 
#		if len(t) == 3:
#			print('Serial read timeout. \n Is the bluetooth app connected AND diplaying Environmental data?')
#			# close serial port
#			ser.close()
#			sys.exit(2)		
	

# close serial port
ser.close()	
pprint(ports)
# Out:
# Found the Thunderboard device to open with PID = 1366 and HID = 1015!
# b'[I] IMU: ACC : 0074,-003,0978\r\n'
# b'[I] IMU: ORI : 0186,0408,2489\r\n'
# b'[I] IMU: ACC : 0063,0000,0996\r\n'
# b'[I] IMU: ORI : 0193,0399,2507\r\n'
# b'[I] IMU: ACC : 0071,0006,0995\r\n'
# b'[I] IMU: ORI : 0186,0391,2519\r\n'
# b'[I] IMU: ACC : 0063,0003,0990\r\n'
# b'[I] IMU: ORI : 0188,0388,2539\r\n'
# b'[I] IMU: ACC : 0076,0000,0968\r\n'
# b'[I] IMU: ORI : 0178,0397,2571\r\n'
# b'[I] IMU: ACC : 0076,-012,0974\r\n'
# b'[I] IMU: ORI : 0182,0398,2581\r\n'
# b'[I] IMU: ACC : 0057,0006,0992\r\n'
# b'[I] IMU: ORI : 0177,0393,2597\r\n'
# b'[I] IMU: ACC : 0076,-001,0989\r\n'
# b'[I] IMU: ORI : 0159,0389,2609\r\n'
# b'[I] IMU: ACC : 0067,-004,0978\r\n'
# b'[I] IMU: ORI : 0159,0389,2634\r\n'
# b'[I] IMU: ACC : 0062,-002,0990\r\n'
# b'[I] IMU: ORI : 0161,0384,2661\r\n'
# b'[I] IMU: ACC : 0067,-010,0993\r\n'
# b'[I] IMU: ORI : 0172,0379,2679\r\n'
# b'[I] IMU: ACC : 0076,-007,0999\r\n'
# b'[I] IMU: ORI : 0173,0386,2700\r\n'
# b'[I] IMU: ACC : 0057,0003,0988\r\n'
# b'[I] IMU: ORI : 0178,0382,2717\r\n'
# b'[I] IMU: ACC : 0064,0002,0977\r\n'
# b'[I] IMU: ORI : 0183,0387,2730\r\n'
# b'[I] IMU: ACC : 0082,-013,0982\r\n'
# b'[I] IMU: ORI : 0188,0395,2757\r\n'
# b'[I] IMU: ACC : 0063,-010,0983\r\n'
# b'[I] IMU: ORI : 0184,0383,2778\r\n'
# b'[I] IMU: ACC : 0068,0006,0987\r\n'
# b'[I] IMU: ORI : 0180,0378,2794\r\n'
# b'[I] IMU: ACC : 0077,-002,0981\r\n'
# b'[I] IMU: ORI : 0180,0375,2812\r\n'
# b'[I] IMU: ACC : 0067,0005,0984\r\n'
# b'[I] IMU: ORI : 0172,0369,2826\r\n'
# b'[I] IMU: ACC : 0078,0000,0991\r\n'
# b'[I] IMU: ORI : 0168,0364,2854\r\n'
# b'[I] IMU: ACC : 0059,-007,0994\r\n'
# b'[I] IMU: ORI : 0176,0356,2875\r\n'
# b'[I] IMU: ACC : 0072,-002,0985\r\n'
# b'[I] IMU: ORI : 0172,0360,2899\r\n'
# b'[I] IMU: ACC : 0079,0013,0988\r\n'
# b'[I] IMU: ORI : 0160,0358,2920\r\n'
# b'[I] IMU: ACC : 0065,-010,1000\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : 0161,0359,2943\r\n'
# b'[I] IMU: ACC : 0074,-004,0982\r\n'
# b'[I] IMU: ORI : 0160,0364,2962\r\n'
# b'[I] IMU: ACC : 0080,-003,0984\r\n'
# b'[I] IMU: ORI : 0163,0366,2978\r\n'
# b'[I] IMU: ACC : 0067,0000,0993\r\n'
# b'[I] IMU: ORI : 0167,0365,2991\r\n'
# b'[I] IMU: ACC : 0062,0000,0988\r\n'
# b'[I] IMU: ORI : 0163,0360,3001\r\n'
# b'[I] IMU: ACC : 0057,-003,0988\r\n'
# b'[I] IMU: ORI : 0155,0356,3011\r\n'
# b'[I] IMU: ACC : 0066,-001,0982\r\n'
# b'[I] IMU: ORI : 0152,0347,3024\r\n'
# b'[I] IMU: ACC : 0071,-001,0985\r\n'
# b'[I] IMU: ORI : 0155,0358,3035\r\n'
# b'[I] IMU: ACC : 0074,-015,0975\r\n'
# b'[I] IMU: ORI : 0166,0368,3057\r\n'
# b'[I] IMU: ACC : 0083,-003,0986\r\n'
# b'[I] IMU: ORI : 0165,0388,3067\r\n'
# b'[I] IMU: ACC : 0076,-003,0985\r\n'
# b'[I] IMU: ORI : 0169,0397,3089\r\n'
# b'[I] IMU: ACC : 0072,-010,0988\r\n'
# b'[I] IMU: ORI : 0176,0398,3113\r\n'
# b'[I] IMU: ACC : 0083,0000,0993\r\n'
# b'[I] IMU: ORI : 0173,0412,3136\r\n'
# b'[I] IMU: ACC : 0057,-009,0974\r\n'
# b'[I] IMU: ORI : 0187,0404,3152\r\n'
# b'[I] IMU: ACC : 0085,-021,0985\r\n'
# b'[I] IMU: ORI : 0211,0405,3165\r\n'
# b'[I] IMU: ACC : 0077,-003,0974\r\n'
# b'[I] IMU: ORI : 0207,0403,3181\r\n'
# b'[I] IMU: ACC : 0068,0000,0983\r\n'
# b'[I] IMU: ORI : 0203,0394,3187\r\n'
# b'[I] IMU: ACC : 0053,0000,0983\r\n'
# b'[I] IMU: ORI : 0192,0378,3207\r\n'
# b'[I] IMU: ACC : 0075,-013,0997\r\n'
# b'[I] IMU: ORI : 0203,0385,3222\r\n'
# b'[I] IMU: ACC : 0066,-007,0987\r\n'
# b'[I] IMU: ORI : 0195,0385,3232\r\n'
# b'[I] IMU: ACC : 0067,0001,0984\r\n'
# b'[I] IMU: ORI : 0188,0392,3244\r\n'
# b'[I] IMU: ACC : 0055,0009,0982\r\n'
# b'[I] IMU: ORI : 0179,0398,3262\r\n'
# b'[I] IMU: ACC : 0070,-001,0982\r\n'
# b'[I] IMU: ORI : 0175,0395,3288\r\n'
# b'[I] IMU: ACC : 0080,0000,0983\r\n'
# b'[I] IMU: ORI : 0177,0407,3313\r\n'
# b'[I] IMU: ACC : 0072,0000,0979\r\n'
# b'[I] IMU: ORI : 0168,0406,3335\r\n'
# b'[I] IMU: ACC : 0069,-001,0987\r\n'
# b'[I] IMU: ORI : 0170,0396,3367\r\n'
# b'[I] IMU: ACC : 0070,-001,0983\r\n'
# b'[I] IMU: ORI : 0160,0392,3381\r\n'
# b'[I] IMU: ACC : 0064,-011,0976\r\n'
# b'[I] IMU: ORI : 0161,0397,3397\r\n'
# b'[I] IMU: ACC : 0060,-012,0994\r\n'
# b'[I] IMU: ORI : 0171,0390,3423\r\n'
# b'[I] IMU: ACC : 0080,-011,0984\r\n'
# b'[I] IMU: ORI : 0169,0399,3440\r\n'
# b'[I] IMU: ACC : 0077,-006,0992\r\n'
# b'[I] IMU: ORI : 0179,0398,3459\r\n'
# b'[I] IMU: ACC : 0076,0005,0994\r\n'
# b'[I] IMU: ORI : 0177,0398,3475\r\n'
# b'[I] IMU: ACC : 0075,-020,0993\r\n'
# b'[I] IMU: ORI : 0190,0398,3486\r\n'
# b'[I] IMU: ACC : 0076,-002,0977\r\n'
# b'[I] IMU: ORI : 0192,0397,3504\r\n'
# b'[I] IMU: ACC : 0057,-001,0979\r\n'
# b'[I] IMU: ORI : 0199,0388,3526\r\n'
# b'[I] IMU: ACC : 0059,-010,0997\r\n'
# b'[I] IMU: ORI : 0198,0378,3547\r\n'
# b'[I] IMU: ACC : 0074,0000,0977\r\n'
# b'[I] IMU: ORI : 0196,0386,3568\r\n'
# b'[I] IMU: ACC : 0081,0004,0985\r\n'
# b'[I] IMU: ORI : 0185,0385,3588\r\n'
# b'[I] IMU: ACC : 0064,-011,0985\r\n'
# b'[I] IMU: ORI : 0190,0381,3609\r\n'
# b'[I] IMU: ACC : 0061,0000,0995\r\n'
# b'[I] IMU: ORI : 0188,0376,3628\r\n'
# b'[I] IMU: ACC : 0054,0000,0991\r\n'
# b'[I] IMU: ORI : 0189,0370,3647\r\n'
# b'[I] IMU: ACC : 0068,-003,0977\r\n'
# b'[I] IMU: ORI : 0178,0368,3664\r\n'
# b'[I] IMU: ACC : 0068,-022,0973\r\n'
# b'[I] IMU: ORI : 0187,0370,3675\r\n'
# b'[I] IMU: ACC : 0078,-006,0981\r\n'
# b'[I] IMU: ORI : 0199,0376,3694\r\n'
# b'[I] IMU: ACC : 0077,-001,0998\r\n'
# b'[I] IMU: ORI : 0196,0382,3711\r\n'
# b'[I] IMU: ACC : 0065,0002,0982\r\n'
# b'[I] IMU: ORI : 0186,0374,3730\r\n'
# b'[I] IMU: ACC : 0073,-009,0997\r\n'
# b'[I] IMU: ORI : 0186,0372,3756\r\n'
# b'[I] IMU: ACC : 0062,-003,0979\r\n'
# b'[I] IMU: ORI : 0182,0372,3771\r\n'
# b'[I] IMU: ACC : 0074,0003,0982\r\n'
# b'[I] IMU: ORI : 0162,0368,3790\r\n'
# b'[I] IMU: ACC : 0076,-012,0999\r\n'
# b'[I] IMU: ORI : 0162,0375,3815\r\n'
# b'[I] IMU: ACC : 0065,-005,0998\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : 0160,0365,3830\r\n'
# b'[I] IMU: ACC : 0076,-003,0973\r\n'
# b'[I] IMU: ORI : 0172,0374,3847\r\n'
# b'[I] IMU: ACC : 0060,0000,0990\r\n'
# b'[I] IMU: ORI : 0172,0366,3860\r\n'
# b'[I] IMU: ACC : 0072,-004,0966\r\n'
# b'[I] IMU: ORI : 0172,0366,3880\r\n'
# b'[I] IMU: ACC : 0062,0000,0975\r\n'
# b'[I] IMU: ORI : 0172,0354,3907\r\n'
# b'[I] IMU: ACC : 0066,0012,0971\r\n'
# b'[I] IMU: ORI : 0171,0362,3923\r\n'
# b'[I] IMU: ACC : 0069,0012,0986\r\n'
# b'[I] IMU: ORI : 0163,0377,3939\r\n'
# b'[I] IMU: ACC : 0050,0000,1000\r\n'
# b'[I] IMU: ORI : 0155,0379,3958\r\n'
# b'[I] IMU: ACC : 0058,0000,0974\r\n'
# b'[I] IMU: ORI : 0149,0378,3978\r\n'
# b'[I] IMU: ACC : 0072,0003,0996\r\n'
# b'[I] IMU: ORI : 0146,0372,3990\r\n'
# b'[I] IMU: ACC : 0052,-001,0981\r\n'
# b'[I] IMU: ORI : 0145,0358,4003\r\n'
# b'[I] IMU: ACC : 0073,-017,0984\r\n'
# b'[I] IMU: ORI : 0150,0375,4021\r\n'
# b'[I] IMU: ACC : 0067,0002,0987\r\n'
# b'[I] IMU: ORI : 0152,0374,4036\r\n'
# b'[I] IMU: ACC : 0070,-009,0979\r\n'
# b'[I] IMU: ORI : 0158,0376,4060\r\n'
# b'[I] IMU: ACC : 0066,-003,0984\r\n'
# b'[I] IMU: ORI : 0162,0379,4080\r\n'
# b'[I] IMU: ACC : 0081,0003,0983\r\n'
# b'[I] IMU: ORI : 0161,0387,4100\r\n'
# b'[I] IMU: ACC : 0072,0006,0986\r\n'
# b'[I] IMU: ORI : 0155,0393,4116\r\n'
# b'[I] IMU: ACC : 0072,0002,0979\r\n'
# b'[I] IMU: ORI : 0151,0398,4125\r\n'
# b'[I] IMU: ACC : 0066,-006,1002\r\n'
# b'[I] IMU: ORI : 0158,0393,4135\r\n'
# b'[I] IMU: ACC : 0078,-003,0982\r\n'
# b'[I] IMU: ORI : 0163,0403,4157\r\n'
# b'[I] IMU: ACC : 0065,-002,0987\r\n'
# b'[I] IMU: ORI : 0164,0406,4166\r\n'
# b'[I] IMU: ACC : 0065,0005,0981\r\n'
# b'[I] IMU: ORI : 0165,0406,4186\r\n'
# b'[I] IMU: ACC : 0067,0001,0968\r\n'
# b'[I] IMU: ORI : 0160,0406,4198\r\n'
# b'[I] IMU: ACC : 0070,0002,0987\r\n'
# b'[I] IMU: ORI : 0147,0400,4220\r\n'
# b'[I] IMU: ACC : 0067,0003,0991\r\n'
# b'[I] IMU: ORI : 0137,0410,4241\r\n'
# b'[I] IMU: ACC : 0065,-005,0989\r\n'
# b'[I] IMU: ORI : 0147,0410,4271\r\n'
# b'[I] IMU: ACC : 0063,0004,0983\r\n'
# b'[I] IMU: ORI : 0133,0404,4283\r\n'
# b'[I] IMU: ACC : 0066,-004,0993\r\n'
# b'[I] IMU: ORI : 0143,0404,4294\r\n'
# b'[I] IMU: ACC : 0077,0005,0988\r\n'
# b'[I] IMU: ORI : 0145,0405,4316\r\n'
# b'[I] IMU: ACC : 0074,0004,0979\r\n'
# b'[I] IMU: ORI : 0143,0392,4331\r\n'
# b'[I] IMU: ACC : 0073,-004,0979\r\n'
# b'[I] IMU: ORI : 0148,0395,4352\r\n'
# b'[I] IMU: ACC : 0067,0000,0989\r\n'
# b'[I] IMU: ORI : 0153,0393,4375\r\n'
# b'[I] IMU: ACC : 0082,0000,0994\r\n'
# b'[I] IMU: ORI : 0152,0392,4396\r\n'
# b'[I] IMU: ACC : 0068,-003,0974\r\n'
# b'[I] IMU: ORI : 0147,0401,4415\r\n'
# b'[I] IMU: ACC : 0083,0005,0994\r\n'
# b'[I] IMU: ORI : 0153,0403,4436\r\n'
# b'[I] IMU: ACC : 0067,-010,0974\r\n'
# b'[I] IMU: ORI : 0158,0394,4451\r\n'
# b'[I] IMU: ACC : 0073,0003,0987\r\n'
# b'[I] IMU: ORI : 0166,0398,4485\r\n'
# b'[I] IMU: ACC : 0072,-003,0995\r\n'
# b'[I] IMU: ORI : 0169,0393,4512\r\n'
# b'[I] IMU: ACC : 0084,0004,0983\r\n'
# b'[I] IMU: ORI : 0157,0392,4536\r\n'
# b'[I] IMU: ACC : 0079,0000,0985\r\n'
# b'[I] IMU: ORI : 0145,0394,4550\r\n'
# b'[I] IMU: ACC : 0076,0004,0983\r\n'
# b'[I] IMU: ORI : 0140,0388,4568\r\n'
# b'[I] IMU: ACC : 0073,-005,1004\r\n'
# b'[I] IMU: ORI : 0149,0390,4583\r\n'
# b'[I] IMU: ACC : 0068,-007,0993\r\n'
# b'[I] IMU: ORI : 0146,0386,4588\r\n'
# b'[I] IMU: ACC : 0065,0000,0973\r\n'
# b'[I] IMU: ORI : 0137,0390,4600\r\n'
# b'[I] IMU: ACC : 0073,-014,0990\r\n'
# b'[I] IMU: ORI : 0145,0395,4618\r\n'
# b'[I] IMU: ACC : 0062,0003,0987\r\n'
# b'[I] IMU: ORI : 0136,0399,4631\r\n'
# b'[I] IMU: ACC : 0081,0000,0982\r\n'
# b'[I] IMU: ORI : 0137,0408,4647\r\n'
# b'[I] IMU: ACC : 0068,0004,0986\r\n'
# b'[I] IMU: ORI : 0133,0397,4679\r\n'
# b'[I] IMU: ACC : 0054,0000,0982\r\n'
# b'[I] IMU: ORI : 0139,0380,4697\r\n'
# b'[I] IMU: ACC : 0064,-011,0972\r\n'
# b'[I] IMU: ORI : 0155,0375,4722\r\n'
# b'[I] IMU: ACC : 0080,-009,0987\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : 0148,0379,4742\r\n'
# b'[I] IMU: ACC : 0078,0000,0985\r\n'
# b'[I] IMU: ORI : 0153,0371,4763\r\n'
# b'[I] IMU: ACC : 0082,0001,0990\r\n'
# b'[I] IMU: ORI : 0156,0372,4787\r\n'
# b'[I] IMU: ACC : 0078,-016,0983\r\n'
# b'[I] IMU: ORI : 0163,0375,4803\r\n'
# b'[I] IMU: ACC : 0062,-017,0974\r\n'
# b'[I] IMU: ORI : 0168,0370,4825\r\n'
# b'[I] IMU: ACC : 0089,-004,0980\r\n'
# b'[I] IMU: ORI : 0167,0378,4843\r\n'
# b'[I] IMU: ACC : 0056,-001,0977\r\n'
# b'[I] IMU: ORI : 0172,0366,4866\r\n'
# b'[I] IMU: ACC : 0061,-019,0985\r\n'
# b'[I] IMU: ORI : -345,2257,3475\r\n'
# b'[I] IMU: ACC : 0052,0014,0989\r\n'
# b'[I] IMU: ORI : -1733,2719,-493\r\n'
# b'[I] IMU: ACC : 0062,0178,-770\r\n'
# b'[I] IMU: ORI : -3783,5758,0115\r\n'
# b'[I] IMU: ACC : 1163,0068,0474\r\n'
# b'[I] IMU: ORI : -1408,5891,1322\r\n'
# b'[I] IMU: ACC : 0842,0032,-139\r\n'
# b'[I] IMU: ORI : -3825,5772,1042\r\n'
# b'[I] IMU: ACC : 0940,-041,-187\r\n'
# b'[I] IMU: ORI : -4521,5501,1910\r\n'
# b'[I] IMU: ACC : 0958,0031,-244\r\n'
# b'[I] IMU: ORI : -6195,5877,1297\r\n'
# b'[I] IMU: ACC : 0934,-032,-047\r\n'
# b'[I] IMU: ORI : -7759,5889,1378\r\n'
# b'[I] IMU: ACC : 0956,-005,-013\r\n'
# b'[I] IMU: ORI : -7986,5922,2273\r\n'
# b'[I] IMU: ACC : 0996,0011,-035\r\n'
# b'[I] IMU: ORI : -7934,5962,2337\r\n'
# b'[I] IMU: ACC : 0985,0023,-047\r\n'
# b'[I] IMU: ORI : -8150,5997,2101\r\n'
# b'[I] IMU: ACC : 1003,0026,-064\r\n'
# b'[I] IMU: ORI : -8144,6018,2096\r\n'
# b'[I] IMU: ACC : 1000,0034,-075\r\n'
# b'[I] IMU: ORI : -8142,6046,2077\r\n'
# b'[I] IMU: ACC : 0998,0026,-060\r\n'
# b'[I] IMU: ORI : -7907,6065,2251\r\n'
# b'[I] IMU: ACC : 1007,0033,-069\r\n'
# b'[I] IMU: ORI : -8005,6094,2116\r\n'
# b'[I] IMU: ACC : 1002,0025,-058\r\n'
# b'[I] IMU: ORI : -7966,6109,2144\r\n'
# b'[I] IMU: ACC : 0996,0028,-070\r\n'
# b'[I] IMU: ORI : -7954,6126,2141\r\n'
# b'[I] IMU: ACC : 1019,0035,-067\r\n'
# b'[I] IMU: ORI : -7926,6151,2161\r\n'
# b'[I] IMU: ACC : 1003,0016,-066\r\n'
# b'[I] IMU: ORI : -7932,6172,2138\r\n'
# b'[I] IMU: ACC : 0999,0020,-073\r\n'
# b'[I] IMU: ORI : -7952,6191,2107\r\n'
# b'[I] IMU: ACC : 1005,0017,-066\r\n'
# b'[I] IMU: ORI : -7895,6207,2157\r\n'
# b'[I] IMU: ACC : 1012,0020,-057\r\n'
# b'[I] IMU: ORI : -7885,6222,2148\r\n'
# b'[I] IMU: ACC : 1000,0026,-061\r\n'
# b'[I] IMU: ORI : -7855,6238,2174\r\n'
# b'[I] IMU: ACC : 0999,0024,-072\r\n'
# b'[I] IMU: ORI : -7839,6249,2175\r\n'
# b'[I] IMU: ACC : 1009,0019,-071\r\n'
# b'[I] IMU: ORI : -7815,6263,2184\r\n'
# b'[I] IMU: ACC : 1015,0022,-064\r\n'
# b'[I] IMU: ORI : -7786,6287,2199\r\n'
# b'[I] IMU: ACC : 1008,0028,-060\r\n'
# b'[I] IMU: ORI : -7753,6304,2211\r\n'
# b'[I] IMU: ACC : 1009,0018,-054\r\n'
# b'[I] IMU: ORI : -7732,6315,2227\r\n'
# b'[I] IMU: ACC : 1000,0021,-069\r\n'
# b'[I] IMU: ORI : -7718,6336,2227\r\n'
# b'[I] IMU: ACC : 1006,0024,-063\r\n'
# b'[I] IMU: ORI : -7731,6363,2205\r\n'
# b'[I] IMU: ACC : 1001,0026,-057\r\n'
# b'[I] IMU: ORI : -7715,6384,2213\r\n'
# b'[I] IMU: ACC : 1005,0019,-061\r\n'
# b'[I] IMU: ORI : -7694,6403,2210\r\n'
# b'[I] IMU: ACC : 1007,0011,-075\r\n'
# b'[I] IMU: ORI : -7656,6417,2232\r\n'
# b'[I] IMU: ACC : 0997,0018,-077\r\n'
# b'[I] IMU: ORI : -7648,6433,2224\r\n'
# b'[I] IMU: ACC : 1014,0018,-077\r\n'
# b'[I] IMU: ORI : -7612,6451,2240\r\n'
# b'[I] IMU: ACC : 1008,0016,-065\r\n'
# b'[I] IMU: ORI : -7614,6468,2235\r\n'
# b'[I] IMU: ACC : 1005,0020,-082\r\n'
# b'[I] IMU: ORI : -7651,6498,2191\r\n'
# b'[I] IMU: ACC : 1001,0022,-065\r\n'
# b'[I] IMU: ORI : -7521,6504,2315\r\n'
# b'[I] IMU: ACC : 1000,0024,-076\r\n'
# b'[I] IMU: ORI : -7504,6521,2315\r\n'
# b'[I] IMU: ACC : 0998,0016,-068\r\n'
# b'[I] IMU: ORI : -7246,6542,2426\r\n'
# b'[I] IMU: ACC : 0996,0040,-084\r\n'
# b'[I] IMU: ORI : -7227,6573,2430\r\n'
# b'[I] IMU: ACC : 0998,0024,-067\r\n'
# b'[I] IMU: ORI : -7252,6593,2388\r\n'
# b'[I] IMU: ACC : 0995,0017,-070\r\n'
# b'[I] IMU: ORI : -7185,6613,2438\r\n'
# b'[I] IMU: ACC : 1012,0014,-081\r\n'
# b'[I] IMU: ORI : -7153,6620,2455\r\n'
# b'[I] IMU: ACC : 1005,0013,-077\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : -7073,6632,2516\r\n'
# b'[I] IMU: ACC : 1006,0018,-062\r\n'
# b'[I] IMU: ORI : -7037,6636,2533\r\n'
# b'[I] IMU: ACC : 1005,0009,-073\r\n'
# b'[I] IMU: ORI : -6931,6637,2630\r\n'
# b'[I] IMU: ACC : 0991,0017,-068\r\n'
# b'[I] IMU: ORI : -6926,6647,2619\r\n'
# b'[I] IMU: ACC : 1004,0018,-065\r\n'
# b'[I] IMU: ORI : -7087,6669,2610\r\n'
# b'[I] IMU: ACC : 1006,0032,-093\r\n'
# b'[I] IMU: ORI : -7080,6680,2607\r\n'
# b'[I] IMU: ACC : 0995,0017,-072\r\n'
# b'[I] IMU: ORI : -7013,6693,2669\r\n'
# b'[I] IMU: ACC : 1009,0028,-062\r\n'
# b'[I] IMU: ORI : -7040,6710,2637\r\n'
# b'[I] IMU: ACC : 1005,0025,-056\r\n'
# b'[I] IMU: ORI : -6978,6731,2679\r\n'
# b'[I] IMU: ACC : 1000,0014,-080\r\n'
# b'[I] IMU: ORI : -6909,6746,2739\r\n'
# b'[I] IMU: ACC : 1012,0014,-078\r\n'
# b'[I] IMU: ORI : -6917,6764,2721\r\n'
# b'[I] IMU: ACC : 0999,0017,-068\r\n'
# b'[I] IMU: ORI : -6885,6780,2740\r\n'
# b'[I] IMU: ACC : 1003,0035,-066\r\n'
# b'[I] IMU: ORI : -6833,6793,2773\r\n'
# b'[I] IMU: ACC : 1016,0019,-076\r\n'
# b'[I] IMU: ORI : -6801,6813,2796\r\n'
# b'[I] IMU: ACC : 1008,0027,-075\r\n'
# b'[I] IMU: ORI : -6798,6840,2783\r\n'
# b'[I] IMU: ACC : 1002,0032,-057\r\n'
# b'[I] IMU: ORI : -6789,6864,2777\r\n'
# b'[I] IMU: ACC : 0991,0028,-060\r\n'
# b'[I] IMU: ORI : -6770,6866,2779\r\n'
# b'[I] IMU: ACC : 1009,0017,-071\r\n'
# b'[I] IMU: ORI : -6692,6880,2835\r\n'
# b'[I] IMU: ACC : 1014,0016,-066\r\n'
# b'[I] IMU: ORI : -6665,6892,2843\r\n'
# b'[I] IMU: ACC : 0998,0018,-063\r\n'
# b'[I] IMU: ORI : -6653,6908,2840\r\n'
# b'[I] IMU: ACC : 1013,0014,-064\r\n'
# b'[I] IMU: ORI : -6631,6929,2851\r\n'
# b'[I] IMU: ACC : 1012,0022,-046\r\n'
# b'[I] IMU: ORI : -6596,6951,2878\r\n'
# b'[I] IMU: ACC : 1007,0019,-065\r\n'
# b'[I] IMU: ORI : -6595,6970,2866\r\n'
# b'[I] IMU: ACC : 1004,0010,-056\r\n'
# b'[I] IMU: ORI : -6547,6982,2905\r\n'
# b'[I] IMU: ACC : 1000,0021,-075\r\n'
# b'[I] IMU: ORI : -6504,6996,2934\r\n'
# b'[I] IMU: ACC : 1004,0012,-082\r\n'
# b'[I] IMU: ORI : -6478,7008,2941\r\n'
# b'[I] IMU: ACC : 1002,0031,-065\r\n'
# b'[I] IMU: ORI : -6470,7034,2929\r\n'
# b'[I] IMU: ACC : 0990,0023,-060\r\n'
# b'[I] IMU: ORI : -6427,7049,2957\r\n'
# b'[I] IMU: ACC : 0993,0017,-066\r\n'
# b'[I] IMU: ORI : -6397,7075,2966\r\n'
# b'[I] IMU: ACC : 1000,0015,-073\r\n'
# b'[I] IMU: ORI : -6348,7092,2998\r\n'
# b'[I] IMU: ACC : 1009,0025,-079\r\n'
# b'[I] IMU: ORI : -6287,7108,3042\r\n'
# b'[I] IMU: ACC : 1007,0018,-073\r\n'
# b'[I] IMU: ORI : -6253,7121,3057\r\n'
# b'[I] IMU: ACC : 0993,0020,-066\r\n'
# b'[I] IMU: ORI : -6210,7134,3084\r\n'
# b'[I] IMU: ACC : 1013,0010,-067\r\n'
# b'[I] IMU: ORI : -6189,7153,3082\r\n'
# b'[I] IMU: ACC : 1010,0026,-065\r\n'
# b'[I] IMU: ORI : -6156,7168,3107\r\n'
# b'[I] IMU: ACC : 0996,0019,-071\r\n'
# b'[I] IMU: ORI : -6098,7179,3142\r\n'
# b'[I] IMU: ACC : 0998,0020,-064\r\n'
# b'[I] IMU: ORI : -6073,7205,3152\r\n'
# b'[I] IMU: ACC : 1009,0003,-070\r\n'
# b'[I] IMU: ORI : -6023,7221,3194\r\n'
# b'[I] IMU: ACC : 1007,0009,-069\r\n'
# b'[I] IMU: ORI : -6019,7239,3193\r\n'
# b'[I] IMU: ACC : 1004,0012,-057\r\n'
# b'[I] IMU: ORI : -5954,7254,3241\r\n'
# b'[I] IMU: ACC : 1000,0013,-069\r\n'
# b'[I] IMU: ORI : -5918,7262,3268\r\n'
# b'[I] IMU: ACC : 1006,0024,-069\r\n'
# b'[I] IMU: ORI : -5865,7279,3311\r\n'
# b'[I] IMU: ACC : 1005,0024,-065\r\n'
# b'[I] IMU: ORI : -5808,7297,3355\r\n'
# b'[I] IMU: ACC : 1009,0027,-066\r\n'
# b'[I] IMU: ORI : -5762,7312,3385\r\n'
# b'[I] IMU: ACC : 0998,0024,-062\r\n'
# b'[I] IMU: ORI : -5665,7329,3467\r\n'
# b'[I] IMU: ACC : 1017,0027,-077\r\n'
# b'[I] IMU: ORI : -5573,7335,3542\r\n'
# b'[I] IMU: ACC : 1004,0014,-056\r\n'
# b'[I] IMU: ORI : -5087,7330,3664\r\n'
# b'[I] IMU: ACC : 0974,0045,-023\r\n'
# b'[I] IMU: ORI : -5884,7357,3703\r\n'
# b'[I] IMU: ACC : 0969,0105,0173\r\n'
# b'[I] IMU: ORI : -5646,7431,3255\r\n'
# b'[I] IMU: ACC : 0882,0009,-121\r\n'
# b'[I] IMU: ORI : -7200,7513,2702\r\n'
# b'[I] IMU: ACC : 0979,0058,-018\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : -7801,7541,2799\r\n'
# b'[I] IMU: ACC : 0993,0027,-078\r\n'
# b'[I] IMU: ORI : -7694,7565,2860\r\n'
# b'[I] IMU: ACC : 1007,0038,-065\r\n'
# b'[I] IMU: ORI : -7695,7578,2849\r\n'
# b'[I] IMU: ACC : 1007,0031,-066\r\n'
# b'[I] IMU: ORI : -7716,7598,2804\r\n'
# b'[I] IMU: ACC : 1010,0026,-062\r\n'
# b'[I] IMU: ORI : -7748,7617,2765\r\n'
# b'[I] IMU: ACC : 0996,0021,-050\r\n'
# b'[I] IMU: ORI : -7703,7637,2794\r\n'
# b'[I] IMU: ACC : 1007,0029,-061\r\n'
# b'[I] IMU: ORI : -7645,7651,2839\r\n'
# b'[I] IMU: ACC : 1003,0029,-067\r\n'
# b'[I] IMU: ORI : -7539,7676,2941\r\n'
# b'[I] IMU: ACC : 1002,0032,-068\r\n'
# b'[I] IMU: ORI : -7442,7691,3025\r\n'
# b'[I] IMU: ACC : 1007,0034,-064\r\n'
# b'[I] IMU: ORI : -7424,7713,3033\r\n'
# b'[I] IMU: ACC : 1007,0030,-060\r\n'
# b'[I] IMU: ORI : -7363,7719,3075\r\n'
# b'[I] IMU: ACC : 1008,0028,-057\r\n'
# b'[I] IMU: ORI : -7310,7728,3102\r\n'
# b'[I] IMU: ACC : 1006,0009,-060\r\n'
# b'[I] IMU: ORI : -7222,7752,3181\r\n'
# b'[I] IMU: ACC : 0990,0033,-055\r\n'
# b'[I] IMU: ORI : -7185,7765,3216\r\n'
# b'[I] IMU: ACC : 1006,0025,-069\r\n'
# b'[I] IMU: ORI : -7167,7786,3222\r\n'
# b'[I] IMU: ACC : 1010,0027,-054\r\n'
# b'[I] IMU: ORI : -7100,7801,3274\r\n'
# b'[I] IMU: ACC : 0989,0023,-069\r\n'
# b'[I] IMU: ORI : -7081,7814,3283\r\n'
# b'[I] IMU: ACC : 0990,0017,-059\r\n'
# b'[I] IMU: ORI : -6977,7831,3362\r\n'
# b'[I] IMU: ACC : 1000,0034,-052\r\n'
# b'[I] IMU: ORI : -6921,7841,3398\r\n'
# b'[I] IMU: ACC : 0990,0028,-065\r\n'
# b'[I] IMU: ORI : -6823,7850,3485\r\n'
# b'[I] IMU: ACC : 0996,0026,-048\r\n'
# b'[I] IMU: ORI : -6748,7860,3552\r\n'
# b'[I] IMU: ACC : 1007,0022,-053\r\n'
# b'[I] IMU: ORI : -6700,7882,3579\r\n'
# b'[I] IMU: ACC : 1004,0021,-055\r\n'
# b'[I] IMU: ORI : -6592,7889,3667\r\n'
# b'[I] IMU: ACC : 1005,0032,-056\r\n'
# b'[I] IMU: ORI : -6478,7898,3765\r\n'
# b'[I] IMU: ACC : 1020,0016,-056\r\n'
# b'[I] IMU: ORI : -6432,7912,3787\r\n'
# b'[I] IMU: ACC : 1002,0026,-057\r\n'
# b'[I] IMU: ORI : -6262,7915,3950\r\n'
# b'[I] IMU: ACC : 1015,0024,-061\r\n'
# b'[I] IMU: ORI : -6222,7935,3977\r\n'
# b'[I] IMU: ACC : 0997,0028,-047\r\n'
# b'[I] IMU: ORI : -6204,7942,3991\r\n'
# b'[I] IMU: ACC : 1007,0020,-054\r\n'
# b'[I] IMU: ORI : -6163,7950,4020\r\n'
# b'[I] IMU: ACC : 1009,0020,-057\r\n'
# b'[I] IMU: ORI : -6200,7961,3974\r\n'
# b'[I] IMU: ACC : 1009,0022,-047\r\n'
# b'[I] IMU: ORI : -6107,7984,4050\r\n'
# b'[I] IMU: ACC : 1004,0035,-038\r\n'
# b'[I] IMU: ORI : -6040,8007,4103\r\n'
# b'[I] IMU: ACC : 1001,0045,-057\r\n'
# b'[I] IMU: ORI : -6003,8026,4130\r\n'
# b'[I] IMU: ACC : 1011,0029,-047\r\n'
# b'[I] IMU: ORI : -5945,8039,4176\r\n'
# b'[I] IMU: ACC : 1007,0022,-055\r\n'
# b'[I] IMU: ORI : -5853,8058,4249\r\n'
# b'[I] IMU: ACC : 0995,0020,-055\r\n'
# b'[I] IMU: ORI : -5809,8067,4279\r\n'
# b'[I] IMU: ACC : 0998,0034,-049\r\n'
# b'[I] IMU: ORI : -5693,8080,4383\r\n'
# b'[I] IMU: ACC : 0997,0037,-051\r\n'
# b'[I] IMU: ORI : -5604,8094,4463\r\n'
# b'[I] IMU: ACC : 0999,0024,-044\r\n'
# b'[I] IMU: ORI : -5554,8112,4491\r\n'
# b'[I] IMU: ACC : 1004,0030,-063\r\n'
# b'[I] IMU: ORI : -5411,8122,4614\r\n'
# b'[I] IMU: ACC : 0991,0029,-057\r\n'
# b'[I] IMU: ORI : -5346,8144,4670\r\n'
# b'[I] IMU: ACC : 1009,0028,-059\r\n'
# b'[I] IMU: ORI : -5284,8159,4721\r\n'
# b'[I] IMU: ACC : 1003,0020,-061\r\n'
# b'[I] IMU: ORI : -5156,8167,4830\r\n'
# b'[I] IMU: ACC : 0990,0032,-051\r\n'
# b'[I] IMU: ORI : -5042,8176,4936\r\n'
# b'[I] IMU: ACC : 1014,0032,-071\r\n'
# b'[I] IMU: ORI : -4940,8183,5018\r\n'
# b'[I] IMU: ACC : 0995,0027,-063\r\n'
# b'[I] IMU: ORI : -4903,8194,5035\r\n'
# b'[I] IMU: ACC : 1014,0015,-061\r\n'
# b'[I] IMU: ORI : -4861,8209,5071\r\n'
# b'[I] IMU: ACC : 1001,0023,-051\r\n'
# b'[I] IMU: ORI : -4747,8219,5169\r\n'
# b'[I] IMU: ACC : 1005,0023,-059\r\n'
# b'[I] IMU: ORI : -4654,8240,5252\r\n'
# b'[I] IMU: ACC : 1004,0027,-052\r\n'
# b'[I] IMU: ORI : -4499,8250,5383\r\n'
# b'[I] IMU: ACC : 1007,0026,-053\r\n'
# b'[I] IMU: ORI : -4353,8253,5520\r\n'
# b'[I] IMU: ACC : 1000,0020,-066\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : -4202,8271,5654\r\n'
# b'[I] IMU: ACC : 0984,0022,-058\r\n'
# b'[I] IMU: ORI : -4004,8280,5837\r\n'
# b'[I] IMU: ACC : 0993,0029,-055\r\n'
# b'[I] IMU: ORI : -3838,8286,5999\r\n'
# b'[I] IMU: ACC : 0998,0032,-062\r\n'
# b'[I] IMU: ORI : -3773,8284,6043\r\n'
# b'[I] IMU: ACC : 1007,0031,-071\r\n'
# b'[I] IMU: ORI : -10372,5402,1176\r\n'
# b'[I] IMU: ACC : 1111,0202,0041\r\n'
# b'[I] IMU: ORI : -8999,3692,2283\r\n'
# b'[I] IMU: ACC : 0830,0624,-103\r\n'
# b'[I] IMU: ORI : -8360,2188,3582\r\n'
# b'[I] IMU: ACC : 0618,0773,0065\r\n'
# b'[I] IMU: ORI : -7736,-626,2696\r\n'
# b'[I] IMU: ACC : 0193,0939,0041\r\n'
# b'[I] IMU: ORI : -7861,-1078,1894\r\n'
# b'[I] IMU: ACC : 0162,0936,0080\r\n'
# b'[I] IMU: ORI : -7957,-1212,2092\r\n'
# b'[I] IMU: ACC : 0068,0985,-006\r\n'
# b'[I] IMU: ORI : -7922,-1254,2004\r\n'
# b'[I] IMU: ACC : 0025,0974,0008\r\n'
# b'[I] IMU: ORI : -7778,-1250,1851\r\n'
# b'[I] IMU: ACC : 0012,0985,0018\r\n'
# b'[I] IMU: ORI : -7820,-1187,1880\r\n'
# b'[I] IMU: ACC : 0007,0979,0038\r\n'
# b'[I] IMU: ORI : -7792,-1113,1807\r\n'
# b'[I] IMU: ACC : 0056,0994,-013\r\n'
# b'[I] IMU: ORI : -7742,-1110,1842\r\n'
# b'[I] IMU: ACC : 0064,0994,0001\r\n'
# b'[I] IMU: ORI : -7790,-1008,1880\r\n'
# b'[I] IMU: ACC : 0033,0985,0003\r\n'
# b'[I] IMU: ORI : -7858,-1031,1920\r\n'
# b'[I] IMU: ACC : 0077,0974,-025\r\n'
# b'[I] IMU: ORI : -8127,-1021,2071\r\n'
# b'[I] IMU: ACC : 0080,0983,0015\r\n'
# b'[I] IMU: ORI : -8053,-950,1960\r\n'
# b'[I] IMU: ACC : 0083,0997,-020\r\n'
# b'[I] IMU: ORI : -8027,-978,1948\r\n'
# b'[I] IMU: ACC : 0095,0982,-005\r\n'
# b'[I] IMU: ORI : -8213,-1139,2138\r\n'
# b'[I] IMU: ACC : 0046,0993,0014\r\n'
# b'[I] IMU: ORI : -8144,-1816,2041\r\n'
# b'[I] IMU: ACC : 0024,0977,0032\r\n'
# b'[I] IMU: ORI : -8011,-1836,1994\r\n'
# b'[I] IMU: ACC : -031,1003,0023\r\n'
# b'[I] IMU: ORI : -8011,-1839,2047\r\n'
# b'[I] IMU: ACC : -093,0965,0058\r\n'
# b'[I] IMU: ORI : -7966,-1818,1865\r\n'
# b'[I] IMU: ACC : -041,0997,0029\r\n'
# b'[I] IMU: ORI : -7901,-1777,1809\r\n'
# b'[I] IMU: ACC : -052,0989,0000\r\n'
# b'[I] IMU: ORI : -7937,-1715,1748\r\n'
# b'[I] IMU: ACC : -047,0980,0014\r\n'
# b'[I] IMU: ORI : -7887,-1644,1563\r\n'
# b'[I] IMU: ACC : -057,0982,0003\r\n'
# b'[I] IMU: ORI : -7959,-1500,1447\r\n'
# b'[I] IMU: ACC : -060,0977,0017\r\n'
# b'[I] IMU: ORI : -7921,-1436,1347\r\n'
# b'[I] IMU: ACC : -032,0999,-003\r\n'
# b'[I] IMU: ORI : -7862,-1421,1338\r\n'
# b'[I] IMU: ACC : -026,0983,-001\r\n'
# b'[I] IMU: ORI : -8105,-1425,1466\r\n'
# b'[I] IMU: ACC : -039,0986,-003\r\n'
# b'[I] IMU: ORI : -8101,-1392,1452\r\n'
# b'[I] IMU: ACC : -029,0977,-021\r\n'
# b'[I] IMU: ORI : -8320,-1403,1602\r\n'
# b'[I] IMU: ACC : -007,0993,-017\r\n'
# b'[I] IMU: ORI : -8330,-1387,1617\r\n'
# b'[I] IMU: ACC : -026,0993,-010\r\n'
# b'[I] IMU: ORI : -8300,-1376,1597\r\n'
# b'[I] IMU: ACC : -020,0981,-019\r\n'
# b'[I] IMU: ORI : -8528,-1343,1747\r\n'
# b'[I] IMU: ACC : -023,0999,-013\r\n'
# b'[I] IMU: ORI : -8515,-1323,1741\r\n'
# b'[I] IMU: ACC : -020,0987,-018\r\n'
# b'[I] IMU: ORI : -8518,-1298,1748\r\n'
# b'[I] IMU: ACC : -023,0982,-021\r\n'
# b'[I] IMU: ORI : -8676,-1299,1881\r\n'
# b'[I] IMU: ACC : -009,1018,-026\r\n'
# b'[I] IMU: ORI : -8676,-1286,1862\r\n'
# b'[I] IMU: ACC : -017,0978,-016\r\n'
# b'[I] IMU: ORI : -8873,-1241,1997\r\n'
# b'[I] IMU: ACC : -017,1002,-021\r\n'
# b'[I] IMU: ORI : -8841,-1213,1956\r\n'
# b'[I] IMU: ACC : -022,0984,-022\r\n'
# b'[I] IMU: ORI : -8829,-1202,1962\r\n'
# b'[I] IMU: ACC : -004,0998,-019\r\n'
# b'[I] IMU: ORI : -8796,-1172,1946\r\n'
# b'[I] IMU: ACC : -012,1000,-009\r\n'
# b'[I] IMU: ORI : -8769,-1150,1957\r\n'
# b'[I] IMU: ACC : -005,1000,-027\r\n'
# b'[I] IMU: ORI : -8724,-1112,2104\r\n'
# b'[I] IMU: ACC : -019,0998,-002\r\n'
# b'[I] IMU: ORI : -7675,-852,2618\r\n'
# b'[I] IMU: ACC : -119,0875,-088\r\n'
# b'[I] IMU: ORI : -8049,-774,3882\r\n'
# b'[I] IMU: ACC : 0223,0774,0331\r\n'
# b'[I] IMU: ORI : -8158,-1029,4790\r\n'
# b'[I] IMU: ACC : 0009,0844,0265\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : -7433,0091,5116\r\n'
# b'[I] IMU: ACC : -100,0831,0018\r\n'
# b'[I] IMU: ORI : -5491,-574,7074\r\n'
# b'[I] IMU: ACC : 0010,0879,0376\r\n'
# b'[I] IMU: ORI : -6072,-1631,7110\r\n'
# b'[I] IMU: ACC : -059,0832,0410\r\n'
# b'[I] IMU: ORI : -6811,-1274,7424\r\n'
# b'[I] IMU: ACC : -266,0893,0275\r\n'
# b'[I] IMU: ORI : -7865,0367,7984\r\n'
# b'[I] IMU: ACC : -120,0950,0322\r\n'
# b'[I] IMU: ORI : -9195,-784,9059\r\n'
# b'[I] IMU: ACC : 0049,0927,0175\r\n'
# b'[I] IMU: ORI : -7781,-1786,8811\r\n'
# b'[I] IMU: ACC : 0029,1109,-044\r\n'
# b'[I] IMU: ORI : -7725,-2252,9136\r\n'
# b'[I] IMU: ACC : -052,1004,0211\r\n'
# b'[I] IMU: ORI : -8030,-466,9140\r\n'
# b'[I] IMU: ACC : 0105,0961,0298\r\n'
# b'[I] IMU: ORI : -9693,-477,10606\r\n'
# b'[I] IMU: ACC : 0045,0971,0255\r\n'
# b'[I] IMU: ORI : -11399,0506,11063\r\n'
# b'[I] IMU: ACC : 0025,0943,-053\r\n'
# b'[I] IMU: ORI : -11570,1231,11733\r\n'
# b'[I] IMU: ACC : 0007,0969,-187\r\n'
# b'[I] IMU: ORI : -11497,1034,11642\r\n'
# b'[I] IMU: ACC : 0109,0952,-231\r\n'
# b'[I] IMU: ORI : -11444,0783,11547\r\n'
# b'[I] IMU: ACC : 0057,1000,-224\r\n'
# b'[I] IMU: ORI : -11499,0742,11487\r\n'
# b'[I] IMU: ACC : 0044,0995,-225\r\n'
# b'[I] IMU: ORI : -11525,0735,11381\r\n'
# b'[I] IMU: ACC : 0041,0996,-233\r\n'
# b'[I] IMU: ORI : -11240,0115,11173\r\n'
# b'[I] IMU: ACC : 0050,0959,-269\r\n'
# b'[I] IMU: ORI : -7254,0239,9075\r\n'
# b'[I] IMU: ACC : -328,0644,0308\r\n'
# b'[I] IMU: ORI : -5151,-381,9572\r\n'
# b'[I] IMU: ACC : 0337,0302,0988\r\n'
# b'[I] IMU: ORI : -4373,-402,8898\r\n'
# b'[I] IMU: ACC : 0057,0057,0973\r\n'
# b'[I] IMU: ORI : -3961,-327,8873\r\n'
# b'[I] IMU: ACC : 0048,0019,0981\r\n'
# b'[I] IMU: ORI : -3565,-270,8856\r\n'
# b'[I] IMU: ACC : 0058,0016,0997\r\n'
# b'[I] IMU: ORI : -3198,-214,8834\r\n'
# b'[I] IMU: ACC : 0066,0016,0993\r\n'
# b'[I] IMU: ORI : -2878,-149,8824\r\n'
# b'[I] IMU: ACC : 0057,0015,0990\r\n'
# b'[I] IMU: ORI : -2589,-092,8816\r\n'
# b'[I] IMU: ACC : 0069,0011,0988\r\n'
# b'[I] IMU: ORI : -2317,-036,8813\r\n'
# b'[I] IMU: ACC : 0051,0020,0986\r\n'
# b'[I] IMU: ORI : -2081,-007,8819\r\n'
# b'[I] IMU: ACC : 0055,0018,0981\r\n'
# b'[I] IMU: ORI : -1863,0035,8825\r\n'
# b'[I] IMU: ACC : 0050,0012,0979\r\n'
# b'[I] IMU: ORI : -1659,0069,8835\r\n'
# b'[I] IMU: ACC : 0061,0013,0981\r\n'
# b'[I] IMU: ORI : -1487,0104,8843\r\n'
# b'[I] IMU: ACC : 0062,0007,0986\r\n'
# b'[I] IMU: ORI : -1334,0127,8849\r\n'
# b'[I] IMU: ACC : 0070,0010,0991\r\n'
# b'[I] IMU: ORI : -1184,0148,8853\r\n'
# b'[I] IMU: ACC : 0057,0007,0990\r\n'
# b'[I] IMU: ORI : -1044,0169,8864\r\n'
# b'[I] IMU: ACC : 0055,0012,0989\r\n'
# b'[I] IMU: ORI : -922,0183,8882\r\n'
# b'[I] IMU: ACC : 0049,0027,0979\r\n'
# b'[I] IMU: ORI : -827,0187,8892\r\n'
# b'[I] IMU: ACC : 0063,0010,0998\r\n'
# b'[I] IMU: ORI : -726,0204,8901\r\n'
# b'[I] IMU: ACC : 0059,0022,0988\r\n'
# b'[I] IMU: ORI : -652,0221,8923\r\n'
# b'[I] IMU: ACC : 0062,0019,0993\r\n'
# b'[I] IMU: ORI : -582,0229,8947\r\n'
# b'[I] IMU: ACC : 0072,0023,0981\r\n'
# b'[I] IMU: ORI : -521,0251,8965\r\n'
# b'[I] IMU: ACC : 0067,0010,0989\r\n'
# b'[I] IMU: ORI : -454,0265,8985\r\n'
# b'[I] IMU: ACC : 0067,0002,0983\r\n'
# b'[I] IMU: ORI : -391,0271,8994\r\n'
# b'[I] IMU: ACC : 0054,0006,0982\r\n'
# b'[I] IMU: ORI : -332,0289,9009\r\n'
# b'[I] IMU: ACC : 0077,0019,0987\r\n'
# b'[I] IMU: ORI : -297,0306,9025\r\n'
# b'[I] IMU: ACC : 0066,0003,1000\r\n'
# b'[I] IMU: ORI : -251,0315,9047\r\n'
# b'[I] IMU: ACC : 0052,0019,0991\r\n'
# b'[I] IMU: ORI : -217,0316,9063\r\n'
# b'[I] IMU: ACC : 0049,0014,0995\r\n'
# b'[I] IMU: ORI : -182,0315,9089\r\n'
# b'[I] IMU: ACC : 0062,0021,0991\r\n'
# b'[I] IMU: ORI : -154,0322,9099\r\n'
# b'[I] IMU: ACC : 0065,0011,0985\r\n'
# b'[I] IMU: ORI : -137,0323,9117\r\n'
# b'[I] IMU: ACC : 0054,0016,0989\r\n'
# b'[I] IMU: ORI : -115,0325,9143\r\n'
# b'[I] IMU: ACC : 0062,0007,0984\r\n'
# b'[I] IMU: ORI : -082,0326,9168\r\n'
# b'[I] IMU: ACC : 0067,0016,0981\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : -066,0335,9188\r\n'
# b'[I] IMU: ACC : 0065,0025,0995\r\n'
# b'[I] IMU: ORI : -046,0330,9211\r\n'
# b'[I] IMU: ACC : 0064,0004,1000\r\n'
# b'[I] IMU: ORI : -025,0329,9230\r\n'
# b'[I] IMU: ACC : 0064,0019,0992\r\n'
# b'[I] IMU: ORI : -014,0340,9253\r\n'
# b'[I] IMU: ACC : 0066,0008,0993\r\n'
# b'[I] IMU: ORI : -002,0347,9277\r\n'
# b'[I] IMU: ACC : 0063,0000,0980\r\n'
# b'[I] IMU: ORI : 0008,0350,9301\r\n'
# b'[I] IMU: ACC : 0056,0004,0983\r\n'
# b'[I] IMU: ORI : 0019,0352,9307\r\n'
# b'[I] IMU: ACC : 0063,0025,0997\r\n'
# b'[I] IMU: ORI : 0018,0351,9316\r\n'
# b'[I] IMU: ACC : 0056,0017,0987\r\n'
# b'[I] IMU: ORI : 0012,0349,9336\r\n'
# b'[I] IMU: ACC : 0065,0021,0982\r\n'
# b'[I] IMU: ORI : 0013,0356,9350\r\n'
# b'[I] IMU: ACC : 0069,0018,0994\r\n'
# b'[I] IMU: ORI : 0021,0360,9375\r\n'
# b'[I] IMU: ACC : 0059,0006,0993\r\n'
# b'[I] IMU: ORI : 0035,0347,9403\r\n'
# b'[I] IMU: ACC : 0061,0018,0981\r\n'
# b'[I] IMU: ORI : 0035,0345,9424\r\n'
# b'[I] IMU: ACC : 0058,0018,0999\r\n'
# b'[I] IMU: ORI : 0038,0344,9434\r\n'
# b'[I] IMU: ACC : 0071,0020,0989\r\n'
# b'[I] IMU: ORI : 0049,0350,9452\r\n'
# b'[I] IMU: ACC : 0071,0009,0991\r\n'
# b'[I] IMU: ORI : 0057,0351,9468\r\n'
# b'[I] IMU: ACC : 0057,0017,0972\r\n'
# b'[I] IMU: ORI : 0061,0349,9489\r\n'
# b'[I] IMU: ACC : 0071,-001,0991\r\n'
# b'[I] IMU: ORI : 0084,0356,9511\r\n'
# b'[I] IMU: ACC : 0051,0012,0983\r\n'
# b'[I] IMU: ORI : 0083,0363,9529\r\n'
# b'[I] IMU: ACC : 0068,0012,0985\r\n'
# b'[I] IMU: ORI : 0077,0358,9545\r\n'
# b'[I] IMU: ACC : 0060,0015,0981\r\n'
# b'[I] IMU: ORI : 0073,0361,9557\r\n'
# b'[I] IMU: ACC : 0064,0011,0974\r\n'
# b'[I] IMU: ORI : 0078,0351,9578\r\n'
# b'[I] IMU: ACC : 0065,0015,0973\r\n'
# b'[I] IMU: ORI : 0078,0352,9586\r\n'
# b'[I] IMU: ACC : 0068,0006,0992\r\n'
# b'[I] IMU: ORI : 0090,0356,9606\r\n'
# b'[I] IMU: ACC : 0059,0020,0999\r\n'
# b'[I] IMU: ORI : 0093,0359,9628\r\n'
# b'[I] IMU: ACC : 0056,0012,0993\r\n'
# b'[I] IMU: ORI : 0099,0354,9652\r\n'
# b'[I] IMU: ACC : 0068,0011,0977\r\n'
# b'[I] IMU: ORI : 0093,0342,9668\r\n'
# b'[I] IMU: ACC : 0054,0008,0990\r\n'
# b'[I] IMU: ORI : 0106,0338,9685\r\n'
# b'[I] IMU: ACC : 0055,0022,0986\r\n'
# b'[I] IMU: ORI : 0099,0332,9700\r\n'
# b'[I] IMU: ACC : 0065,0008,0994\r\n'
# b'[I] IMU: ORI : 0105,0335,9718\r\n'
# b'[I] IMU: ACC : 0055,0002,0978\r\n'
# b'[I] IMU: ORI : 0121,0320,9729\r\n'
# b'[I] IMU: ACC : 0050,0016,0973\r\n'
# b'[I] IMU: ORI : 0118,0324,9755\r\n'
# b'[I] IMU: ACC : 0055,0004,0988\r\n'
# b'[I] IMU: ORI : 0117,0331,9776\r\n'
# b'[I] IMU: ACC : 0061,0010,0986\r\n'
# b'[I] IMU: ORI : 0109,0328,9793\r\n'
# b'[I] IMU: ACC : 0043,0014,0993\r\n'
# b'[I] IMU: ORI : 0108,0322,9814\r\n'
# b'[I] IMU: ACC : 0061,0006,0985\r\n'
# b'[I] IMU: ORI : 0117,0318,9844\r\n'
# b'[I] IMU: ACC : 0064,0022,0986\r\n'
# b'[I] IMU: ORI : 0121,0326,9861\r\n'
# b'[I] IMU: ACC : 0059,0005,0987\r\n'
# b'[I] IMU: ORI : 0127,0318,9884\r\n'
# b'[I] IMU: ACC : 0049,0009,0976\r\n'
# b'[I] IMU: ORI : 0121,0318,9901\r\n'
# b'[I] IMU: ACC : 0061,0001,0993\r\n'
# b'[I] IMU: ORI : 0123,0314,9922\r\n'
# b'[I] IMU: ACC : 0057,0006,0987\r\n'
# b'[I] IMU: ORI : 0121,0324,9945\r\n'
# b'[I] IMU: ACC : 0053,0004,0984\r\n'
# b'[I] IMU: ORI : 0125,0312,9965\r\n'
# b'[I] IMU: ACC : 0063,0003,0988\r\n'
# b'[I] IMU: ORI : 0134,0316,9984\r\n'
# b'[I] IMU: ACC : 0072,0007,0989\r\n'
# b'[I] IMU: ORI : 0133,0328,9997\r\n'
# b'[I] IMU: ACC : 0066,0011,0987\r\n'
# b'[I] IMU: ORI : 0128,0332,10018\r\n'
# b'[I] IMU: ACC : 0065,0019,0994\r\n'
# b'[I] IMU: ORI : 0119,0331,10042\r\n'
# b'[I] IMU: ACC : 0066,0019,0988\r\n'
# b'[I] IMU: ORI : 0115,0332,10058\r\n'
# b'[I] IMU: ACC : 0071,0009,0987\r\n'
# b'[I] IMU: ORI : 0126,0340,10076\r\n'
# b'[I] IMU: ACC : 0074,0024,0994\r\n'
# b'[I] IMU: ORI : 0117,0342,10100\r\n'
# b'[I] IMU: ACC : 0054,0002,0986\r\n'
# b'[I] IMU: ORI : 0118,0337,10119\r\n'
# b'[I] IMU: ACC : 0062,0005,0989\r\n'
# b'[I] IMU: ORI : 0114,0339,10137\r\n'
# b'[I] IMU: ACC : 0053,0013,0987\r\n'
# b'[I] Battery level = 100 %\r\n'
# b'[I] IMU: ORI : 0099,0324,10154\r\n'
# b'[I] IMU: ACC : 0052,0016,0984\r\n'
# b'[I] IMU: ORI : 0095,0316,10178\r\n'
# b'[I] IMU: ACC : 0061,0019,0977\r\n'
# b'[I] IMU: ORI : 0103,0323,10198\r\n'
# b'[I] IMU: ACC : 0058,0015,0988\r\n'
# b'[I] IMU: ORI : 0108,0323,10219\r\n'
# b'[I] IMU: ACC : 0066,0006,0970\r\n'
# b'[I] IMU: ORI : 0111,0320,10232\r\n'
# b'[I] IMU: ACC : 0060,0011,1004\r\n'
# b'[I] IMU: ORI : 0111,0310,10257\r\n'
# b'[I] IMU: ACC : 0061,0008,0995\r\n'
# b'[I] IMU: ORI : 0100,0312,10276\r\n'
# b'[I] IMU: ACC : 0065,0017,0980\r\n'
# b'[I] IMU: ORI : 0098,0322,10297\r\n'
# b'[I] IMU: ACC : 0060,0005,0989\r\n'
# b'[I] IMU: ORI : 0105,0314,10316\r\n'
# b'[I] IMU: ACC : 0065,0010,0988\r\n'
# b'[I] IMU: ORI : 0098,0319,10339\r\n'
# b'[I] IMU: ACC : 0055,0008,0986\r\n'
# b'[I] IMU: ORI : 0109,0310,10359\r\n'
# b'[I] IMU: ACC : 0070,0005,0990\r\n'
# b'[I] IMU: ORI : 0112,0310,10376\r\n'
# b'[I] IMU: ACC : 0045,0012,0993\r\n'
# b'[I] IMU: ORI : 0116,0298,10393\r\n'
# b'[I] IMU: ACC : 0064,0012,0987\r\n'
# b'[I] IMU: ORI : 0115,0307,10411\r\n'
# b'[I] IMU: ACC : 0059,0010,0979\r\n'
# b'[I] IMU: ORI : 0121,0314,10436\r\n'
# b'[I] IMU: ACC : 0066,0014,0984\r\n'
# b'[I] IMU: ORI : 0116,0319,10461\r\n'
# b'[I] IMU: ACC : 0060,0021,0990\r\n'
# b'[I] IMU: ORI : 0103,0322,10487\r\n'
# b'[I] IMU: ACC : 0051,0027,0977\r\n'
# b'[I] IMU: ORI : 0097,0316,10505\r\n'
# b'[I] IMU: ACC : 0059,0019,0995\r\n'
# b'[I] IMU: ORI : 0095,0316,10516\r\n'
# b'[I] IMU: ACC : 0071,0016,0985\r\n'
# b'[I] IMU: ORI : 0095,0321,10535\r\n'
# b'[I] IMU: ACC : 0056,0004,0976\r\n'
# b'[I] IMU: ORI : 0089,0320,10555\r\n'
# b'[I] IMU: ACC : 0054,-004,0988\r\n'
# b'[I] IMU: ORI : 0093,0319,10564\r\n'
# b'[I] IMU: ACC : 0070,0008,0986\r\n'
# b'[I] IMU: ORI : 0100,0311,10574\r\n'
# b'[I] IMU: ACC : 0053,0003,0998\r\n'
# b'[I] IMU: ORI : 0111,0300,10599\r\n'
# b'[I] IMU: ACC : 0070,0011,0988\r\n'
# b'[I] IMU: ORI : 0108,0304,10613\r\n'
# b'[I] IMU: ACC : 0055,0009,0981\r\n'
# b'[I] IMU: ORI : 0112,0300,10635\r\n'
# b'[I] IMU: ACC : 0059,0015,0998\r\n'
# b'[I] IMU: ORI : 0107,0308,10650\r\n'
# b'[I] IMU: ACC : 0078,0020,0988\r\n'
# b'[I] IMU: ORI : 0135,0239,9552\r\n'
# b'[I] IMU: ACC : -012,0134,0976\r\n'
# b'[I] IMU: ORI : 0065,0206,9200\r\n'
# b'[I] IMU: ACC : 0166,-050,0961\r\n'
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# /tmp/ipykernel_219029/2099821602.py in <module>
#      69
#      70 while(elapsed_time < float(10)):
# ---> 71         t = str(ser.readline())
#      72         print(t)  # add this
#      73
#
# ~/.local/lib/python3.8/site-packages/serial/serialposix.py in read(self, size)
#     593                     # behavior that they are always ready to read immediately
#     594                     # but reading returns nothing.
# --> 595                     raise SerialException(
#     596                         'device reports readiness to read but returned no data '
#     597                         '(device disconnected or multiple access on port?)')
#
# SerialException: device reports readiness to read but returned no data (device disconnected or multiple access on port?)

# %%
	now = datetime.datetime.now() # current date and time for saving files 
	date_time = now.strftime("%Y_%m_%d_%H_%M_%S")

	os_platform = platform.system()
	appnope.nope()
	plt.style.use('ggplot')

	# temporary sensor keys for input arguments (no spaces)
	sensor_keys = ['TVOC', 'Pressure', 'SoundLevel', 'AmbLight', 
			  	  'eCO2', 'HALL', 'Temp', 'Humidity', 'UVIndex']
	sensor_list = ', '.join(sensor_keys)

	parser = argparse.ArgumentParser()
	parser.add_argument("--time", 
						help="The time for data collection in seconds", 
						default = 10)
	parser.add_argument("--sensor", 
						help="The name of the sensor to plot and display (can be all)\nOptions are: {}".format(sensor_list), 
						default = 'Humidity')
	args = parser.parse_args()
	run_time = float(args.time) # seconds [TODO: input]
	sensor_to_display = str(args.sensor) # 'Humidity' # [TODO: input]

	if sensor_to_display == 'AmbLight':
		sensor_to_display = 'Amb light'
	if sensor_to_display == 'HALL':
		sensor_to_display = 'HALL: Mag'
	if sensor_to_display == 'UVIndex':
		sensor_to_display = 'UV Index'

	# fix sensor keys to match the strings from the Thunderboard
	sensor_keys = ['TVOC', 'Pressure', 'SoundLevel', 'Amb light', 
			  	  'eCO2', 'HALL: Mag', 'Temp', 'Humidity', 'UV Index']

	def TimestampMillisec64():
	    return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000) 

	# serial parameters and serial opening
	baudrate = 115200

	import serial.tools.list_ports
	ports = list(serial.tools.list_ports.comports())
	
	pid = '1366'
	hid = '1015'

	for p in ports:
		#print('Serial port found:')
		#print(p[1])
		#print('Port pid and hid')
		#print(p.hwid)
		hwid_save = p.hwid
		if pid and hid in p.hwid:
			print('Found the Thunderboard device to open with PID = {} and HID = {}!'.format(pid, hid))
	try:
		# ser_addr = [x for x in ports if x[1]=='J-Link OB'][0][0]
		ser_addr = [x for x in ports if pid and hid in x.hwid][0][0]
	except IndexError:
		print('No serial address found.\n Is the thunderboard connected using USB?') 
		if os_platform in ['Darwin', 'Linux']:
			print('Check for /dev/tty.usbmodem by $ ls /dev/tty.*')	
		elif os_platform in ['Windows']:
			print('Check for COM in Device Manager')
		sys.exit(1) 	

	'''
	if os_platform == 'Darwin':  # MAC 
		print("Found these devices: " + glob.glob("/dev/tty.usbmodem*")[0])
		ser_addr = glob.glob("/dev/tty.usbmodem*")[0]
	elif os_platform == 'Windows':
		print("Found these devices: " + glob.glob("/dev/tty.usbmodem*")[0])
		ser_addr = glob.glob("/dev/tty.usbmodem*")[0]
	elif os_platform == 'Linux':
		print("Found these devices: " + glob.glob("/dev/tty.usbmodem*")[0])
		ser_addr = glob.glob("/dev/tty.usbmodem*")[0]
	'''

	ser = serial.Serial(ser_addr, baudrate = baudrate, timeout = 2)
	ser.is_open
	time.sleep(0.15)

	results = {}
	for k in sensor_keys:
		results[k] = {}
		results[k]['value'] = np.array([])
		results[k]['time'] = np.array([])
		results[k]['units'] = np.array([])

	# flush serial buffer
	ser.read(ser.in_waiting)
	t_junk = ser.readline()

	t_start = TimestampMillisec64()
	elapsed_time = (TimestampMillisec64() - t_start)/1000

	while(elapsed_time < run_time):
		t = str(ser.readline())
		print(t)  # add this
		
		# Remove for iOS 
#		if len(t) == 3:
#			print('Serial read timeout. \n Is the bluetooth app connected AND diplaying Environmental data?')
#			# close serial port
#			ser.close()
#			sys.exit(2)		
		
		elapsed_time = (TimestampMillisec64() - t_start) / 1000

		for k in sensor_keys:
			if k in t:
				if k == 'UV Index':
					results[k]['value'] = np.append(results[k]['value'], 
													float(t.split('=')[1].split(' ')[1].replace("\\r\\n'",'')))
					results[k]['units'] = np.append(results[k]['units'], 'index')
				else:
					results[k]['value'] = np.append(results[k]['value'], 
													float(t.split('=')[1].split(' ')[1]))
					# fix units for TVOC and eCO2
					if k == 'eCO2':
						results[k]['units'] = np.append(results[k]['units'], 'ppm')
					elif k == 'TVOC':
						results[k]['units'] = np.append(results[k]['units'], 'ppb')
					else:
						results[k]['units'] = np.append(results[k]['units'], 
													t.split('=')[1].split(' ')[2].replace("\\r\\n'",''))

				results[k]['time'] = np.append(results[k]['time'], elapsed_time)
				if ((k == sensor_to_display) or (sensor_to_display == 'all')):
					print('At {:2.2f} [s] Measured {} sensor: {:4.2f} {}'.format(elapsed_time, 
						k, results[k]['value'][-1], results[k]['units'][-1]))

	# close serial port
	ser.close()

	# plot and save data
	if sensor_to_display == 'all':
		fig, axs = plt.subplots(3,3, figsize = (10, 10))
		sensors_to_plot = sensor_keys
		for idx,k in enumerate(sensors_to_plot):
			axs[int(idx/3)][idx % 3].plot(results[k]['time'], 
					results[k]['value'], marker='x', label = k)
			axs[int(idx/3)][idx % 3].legend() 
			axs[int(idx/3)][idx % 3].set_ylabel(results[k]['units'][-1])
			axs[int(idx/3)][idx % 3].set_xlabel('Time [s]')

	else:
		sensors_to_plot = [sensor_to_display]
		fig, axs = plt.subplots(figsize = (10, 10))
		for idx,k in enumerate(sensors_to_plot):
			axs.plot(results[k]['time'], 
						results[k]['value'], marker='x', label = k)
			axs.set_ylabel(results[k]['units'][-1])
		axs.set_xlabel('Time [s]')
		axs.legend() 


	fig.tight_layout()
	fig.savefig('measured_{}_{}.png'.format(sensor_to_display, date_time))
	# blocking show
	plt.ioff()
	plt.show()
				
	# https://stackoverflow.com/questions/13575090/construct-pandas-dataframe-from-items-in-nested-dictionary
	# save dictionary to CSV file by first converting to a pandas dataframe
	df = pd.DataFrame.from_dict({i + '_' + j: results[i][j] 
	                           for i in results.keys() 
	                           for j in results[i].keys()},
	                       orient='index')
	df = df.transpose()
	df.to_csv('data_{}.csv'.format(date_time), index=False)
# Out:
#   File "/tmp/ipykernel_219029/2588557622.py", line 1
#     import thunderboard-reader
#                        ^
# SyntaxError: invalid syntax
